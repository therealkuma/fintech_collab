# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from pathlib import Path
from hvplot import pandas

loan_data = Path("../fintech_collab/loan_data.xlsx")

loan_df = pd.read_excel(loan_data, header=0, index_col="Loan ID")

#loan_df['Purchase_Date'] = (datetime.utcfromtimestamp(0) + timedelta(loan_df['Purchase Date']).strftime("%Y-%m-%d"))

loan_df.columns = loan_df.columns.str.strip()
loan_df.columns 

#for i in loan_df.columns

b = loan_df['Beginning Period Principal Outstanding'].sum()
e = loan_df['Ending Principal Outstanding'].sum()
print(f"Beginning balance is {b:,}")
print(f"Ending balance is {e:,}")
# loan_df.columns
loan_df.head()

loan_df_pie = loan_df.groupby('Category')['Ending Principal Outstanding'].sum()
# loan_df.plot(x='Funded_Date', legend=True, stacked=True, rot=90)
loan_df_pie.plot.pie()
loan_df_pie

loan_df.head()
# Out:
# Beginning balance is 47,927,569.16
# Ending balance is 57,185,195.94
#         Origination Date Purchase Date  Sold Date     Segment  Term   Status  \
# Loan ID
# 131223        2020-01-15    2022-02-11        NaN  NEAR_PRIME    36   CLOSED
# 971875        2021-12-30    2022-01-03        NaN  NEAR_PRIME    36  Current
# 112774        2021-12-30    2022-01-03        NaN  NEAR_PRIME    36  Current
# 659070        2022-01-10    2022-01-13        NaN       PRIME    60  Current
# 399956        2021-12-29    2022-01-03        NaN  NEAR_PRIME    36  Current
#
#          Days Past Due  Loan Amount  Beginning Period Principal Outstanding  \
# Loan ID
# 131223             122         6000                                    0.00
# 971875               0        25000                                21611.50
# 112774               0        10000                                 8949.94
# 659070               0        13000                                12165.50
# ...

# %%
loan_df_pie = loan_df.groupby('Status')['Ending Principal Outstanding'].sum()
# loan_df.plot(x='Funded_Date', legend=True, stacked=True, rot=90)

loan_df_pie
# Out:
# Status
# CLOSED                   0.00
# Current           56690745.64
# Past Due (16+)      237593.96
# Past Due (30+)      107989.88
# Past Due (60+)       90951.20
# Past Due (90+)       57915.26
# SOLD                     0.00
# Name: Ending Principal Outstanding, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from pathlib import Path
from hvplot import pandas

loan_data = Path("../fintech_collab/loan_data.xlsx")
loan_df.head()


sns.set_context("talk", font_scale= 1)
plt.figure(figsize=(25,6))
sns.scatterplot(x="Loan Amount", y="Days Past Due", data=loan_df)
plt.xlabel("Loan Amount")
plt.ylabel("Days Past Due")
plt.savefig("Seaborn_scatterplot.png",
                    format='png',dpi=150)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from pathlib import Path
from hvplot import pandas

loan_data = Path("../fintech_collab/loan_data.xlsx")
loan_df.head()


sns.set_context("talk", font_scale= 1)
plt.figure(figsize=(15,6))
sns.scatterplot(x="FICO_Range", y="Days Past Due", data=loan_df)
plt.xlabel("Loan Amount")
plt.ylabel("Days Past Due")
plt.savefig("Seaborn_scatterplot.png",
                    format='png',dpi=150)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from pathlib import Path
from hvplot import pandas

loan_data = Path("../fintech_collab/loan_data.xlsx")
loan_df.head()


sns.set_context("talk", font_scale= 1)
plt.figure(figsize=(15,6))
sns.scatterplot(x="Loan_Segment", y="Days Past Due", data=loan_df)
plt.xlabel("Loan Amount")
plt.ylabel("Days Past Due")
plt.savefig("Seaborn_scatterplot.png",
                    format='png',dpi=150)
